# %% [markdown]
# # Evaluation
# Time-based split and metric table for K values.

# %%
from recommender.evaluator import Evaluator
from recommender.hybrid import HybridRecommender
from recommender.utils import load_data
p,u,i = load_data()
m = HybridRecommender().fit(p,u,i)
ev = Evaluator()
results = ev.evaluate(m, i, p, [5,10,20])
ev.print_report(results)
