# %% [markdown]
# # Hybrid Recommender
# Adaptive alpha, festival mode, new arrivals, and save step.

# %%
from pathlib import Path
from recommender.hybrid import HybridRecommender
from recommender.utils import load_data
p,u,i = load_data()
m = HybridRecommender().fit(p,u,i)
for user in ['U0001','U0042','U0200']:
    display(m.recommend(user, 5))
print('July')
display(m.recommend('U0042', 10, {'month':7}))
print('Dashain')
display(m.recommend('U0042', 10, {'month':10}))
print('new arrivals surfaced', sum(r['is_new_arrival'] for r in m.recommend('U0042', 50)))
Path('models').mkdir(exist_ok=True)
m.save(Path('models/hybrid_recommender.pkl'))
# Out:
# [{'product_id': 'P0064',
#   'name': 'NepTech Sunglasses 64',
#   'category': 'Fashion & Accessories',
#   'subcategory': 'Sunglasses',
#   'brand': 'NepTech',
#   'price_npr': 350,
#   'avg_rating': 4.7,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.48480888605719097,
#   'cb_score': 1.0,
#   'hybrid_score': 1.0542404443028597,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0337',
#   'name': 'NepTech Sunglasses 337',
#   'category': 'Fashion & Accessories',
#   'subcategory': 'Sunglasses',
#   'brand': 'NepTech',
#   'price_npr': 4200,
#   'avg_rating': 3.6,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.48480888605719097,
#   'cb_score': 1.0,
#   'hybrid_score': 1.0542404443028597,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0078',
#   'name': 'Kathmandu Craft Sunglasses 78',
#   'category': 'Fashion & Accessories',
#   'subcategory': 'Sunglasses',
#   'brand': 'Kathmandu Craft',
#   'price_npr': 6500,
#   'avg_rating': 4.3,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.48480888605719097,
#   'cb_score': 0.7641830740466333,
#   'hybrid_score': 0.8302143646471611,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0016',
#   'name': 'NepTech Sunglasses 16',
#   'category': 'Fashion & Accessories',
#   'subcategory': 'Sunglasses',
#   'brand': 'NepTech',
#   'price_npr': 1250,
#   'avg_rating': 4.1,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.5336727846636599,
#   'cb_score': 1.0,
#   'hybrid_score': 0.743520031565013,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0381',
#   'name': 'NepTech Sunglasses 381',
#   'category': 'Fashion & Accessories',
#   'subcategory': 'Sunglasses',
#   'brand': 'NepTech',
#   'price_npr': 1800,
#   'avg_rating': 3.8,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.45171564804160796,
#   'cb_score': 1.0,
#   'hybrid_score': 0.6984436064228845,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False}]
# [{'product_id': 'P0278',
#   'name': 'Kathmandu Craft Accessories 278',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Kathmandu Craft',
#   'price_npr': 1250,
#   'avg_rating': 4.4,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.3337925401603879,
#   'cb_score': 0.6778260692309035,
#   'hybrid_score': 0.7406243927773776,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0484',
#   'name': 'Kathmandu Craft Accessories 484',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Kathmandu Craft',
#   'price_npr': 550,
#   'avg_rating': 4.7,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.3337925401603879,
#   'cb_score': 0.6778260692309035,
#   'hybrid_score': 0.7406243927773776,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0334',
#   'name': 'Janakpur Mart Accessories 334',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Janakpur Mart',
#   'price_npr': 14500,
#   'avg_rating': 4.2,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.3337925401603879,
#   'cb_score': 0.6701745704420652,
#   'hybrid_score': 0.7333554689279812,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0266',
#   'name': 'NepTech Accessories 266',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'NepTech',
#   'price_npr': 2500,
#   'avg_rating': 4.1,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.4732428985646965,
#   'cb_score': 1.0,
#   'hybrid_score': 0.7102835942105832,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0265',
#   'name': 'Sagarmatha Accessories 265',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Sagarmatha',
#   'price_npr': 550,
#   'avg_rating': 4.2,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.5267024713366266,
#   'cb_score': 0.7387927598480573,
#   'hybrid_score': 0.6221431011667704,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False}]
# [{'product_id': 'P0411',
#   'name': 'NepTech Shoes 411',
#   'category': 'Fashion & Accessories',
#   'subcategory': 'Shoes',
#   'brand': 'NepTech',
#   'price_npr': 350,
#   'avg_rating': 3.4,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.5047597113721032,
#   'cb_score': 0.8119544910424046,
#   'hybrid_score': 0.8765947520588894,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0375',
#   'name': 'Lalitpur Looms Shoes 375',
#   'category': 'Fashion & Accessories',
#   'subcategory': 'Shoes',
#   'brand': 'Lalitpur Looms',
#   'price_npr': 1800,
#   'avg_rating': 4.0,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.5047597113721032,
#   'cb_score': 0.7608968200293466,
#   'hybrid_score': 0.8280899645964843,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0031',
#   'name': 'Janakpur Mart Shoes 31',
#   'category': 'Fashion & Accessories',
#   'subcategory': 'Shoes',
#   'brand': 'Janakpur Mart',
#   'price_npr': 4200,
#   'avg_rating': 4.3,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.5047597113721032,
#   'cb_score': 0.7461413792728097,
#   'hybrid_score': 0.8140722958777742,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0138',
#   'name': 'NepTech Shoes 138',
#   'category': 'Fashion & Accessories',
#   'subcategory': 'Shoes',
#   'brand': 'NepTech',
#   'price_npr': 6500,
#   'avg_rating': 4.0,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.6423267678328652,
#   'cb_score': 0.8119544910424046,
#   'hybrid_score': 0.6847336986352501,
#   'alpha_used': 0.75,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0391',
#   'name': 'Kathmandu Craft Shoes 391',
#   'category': 'Fashion & Accessories',
#   'subcategory': 'Shoes',
#   'brand': 'Kathmandu Craft',
#   'price_npr': 1800,
#   'avg_rating': 3.3,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.628099324036089,
#   'cb_score': 0.7513675403700024,
#   'hybrid_score': 0.6589163781195674,
#   'alpha_used': 0.75,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False}]
# July
# [{'product_id': 'P0278',
#   'name': 'Kathmandu Craft Accessories 278',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Kathmandu Craft',
#   'price_npr': 1250,
#   'avg_rating': 4.4,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.3337925401603879,
#   'cb_score': 0.6778260692309035,
#   'hybrid_score': 0.7406243927773776,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0484',
#   'name': 'Kathmandu Craft Accessories 484',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Kathmandu Craft',
#   'price_npr': 550,
#   'avg_rating': 4.7,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.3337925401603879,
#   'cb_score': 0.6778260692309035,
#   'hybrid_score': 0.7406243927773776,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0334',
#   'name': 'Janakpur Mart Accessories 334',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Janakpur Mart',
#   'price_npr': 14500,
#   'avg_rating': 4.2,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.3337925401603879,
#   'cb_score': 0.6701745704420652,
#   'hybrid_score': 0.7333554689279812,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0266',
#   'name': 'NepTech Accessories 266',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'NepTech',
#   'price_npr': 2500,
#   'avg_rating': 4.1,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.4732428985646965,
#   'cb_score': 1.0,
#   'hybrid_score': 0.7102835942105832,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0265',
#   'name': 'Sagarmatha Accessories 265',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Sagarmatha',
#   'price_npr': 550,
#   'avg_rating': 4.2,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.5267024713366266,
#   'cb_score': 0.7387927598480573,
#   'hybrid_score': 0.6221431011667704,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0494',
#   'name': 'Himalaya Accessories 494',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Himalaya',
#   'price_npr': 550,
#   'avg_rating': 4.2,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.47585995602891684,
#   'cb_score': 0.7481765122057734,
#   'hybrid_score': 0.5984024063085023,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0405',
#   'name': 'Himalaya Accessories 405',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Himalaya',
#   'price_npr': 14500,
#   'avg_rating': 4.3,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.4403758244524862,
#   'cb_score': 0.7481765122057734,
#   'hybrid_score': 0.5788861339414655,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0169',
#   'name': 'Janakpur Mart Accessories 169',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Janakpur Mart',
#   'price_npr': 9800,
#   'avg_rating': 4.5,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.43997479938122663,
#   'cb_score': 0.6701745704420652,
#   'hybrid_score': 0.5435646963586039,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0419',
#   'name': 'Kathmandu Craft Accessories 419',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Kathmandu Craft',
#   'price_npr': 2500,
#   'avg_rating': 5.0,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.401092589024161,
#   'cb_score': 0.6778260692309035,
#   'hybrid_score': 0.5256226551171951,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0216',
#   'name': 'Lalitpur Looms Accessories 216',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Lalitpur Looms',
#   'price_npr': 1800,
#   'avg_rating': 3.6,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.3571634319598238,
#   'cb_score': 0.6857428594366292,
#   'hybrid_score': 0.5050241743243862,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False}]
# Dashain
# [{'product_id': 'P0278',
#   'name': 'Kathmandu Craft Accessories 278',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Kathmandu Craft',
#   'price_npr': 1250,
#   'avg_rating': 4.4,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.3337925401603879,
#   'cb_score': 0.6778260692309035,
#   'hybrid_score': 0.7406243927773776,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0484',
#   'name': 'Kathmandu Craft Accessories 484',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Kathmandu Craft',
#   'price_npr': 550,
#   'avg_rating': 4.7,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.3337925401603879,
#   'cb_score': 0.6778260692309035,
#   'hybrid_score': 0.7406243927773776,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0334',
#   'name': 'Janakpur Mart Accessories 334',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Janakpur Mart',
#   'price_npr': 14500,
#   'avg_rating': 4.2,
#   'in_stock': True,
#   'is_new_arrival': True,
#   'cf_score': 0.3337925401603879,
#   'cb_score': 0.6701745704420652,
#   'hybrid_score': 0.7333554689279812,
#   'alpha_used': 0.05,
#   'freshness_boost_applied': True,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0266',
#   'name': 'NepTech Accessories 266',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'NepTech',
#   'price_npr': 2500,
#   'avg_rating': 4.1,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.4732428985646965,
#   'cb_score': 1.0,
#   'hybrid_score': 0.7102835942105832,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0265',
#   'name': 'Sagarmatha Accessories 265',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Sagarmatha',
#   'price_npr': 550,
#   'avg_rating': 4.2,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.5267024713366266,
#   'cb_score': 0.7387927598480573,
#   'hybrid_score': 0.6221431011667704,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0494',
#   'name': 'Himalaya Accessories 494',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Himalaya',
#   'price_npr': 550,
#   'avg_rating': 4.2,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.47585995602891684,
#   'cb_score': 0.7481765122057734,
#   'hybrid_score': 0.5984024063085023,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0405',
#   'name': 'Himalaya Accessories 405',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Himalaya',
#   'price_npr': 14500,
#   'avg_rating': 4.3,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.4403758244524862,
#   'cb_score': 0.7481765122057734,
#   'hybrid_score': 0.5788861339414655,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0169',
#   'name': 'Janakpur Mart Accessories 169',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Janakpur Mart',
#   'price_npr': 9800,
#   'avg_rating': 4.5,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.43997479938122663,
#   'cb_score': 0.6701745704420652,
#   'hybrid_score': 0.5435646963586039,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0419',
#   'name': 'Kathmandu Craft Accessories 419',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Kathmandu Craft',
#   'price_npr': 2500,
#   'avg_rating': 5.0,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.401092589024161,
#   'cb_score': 0.6778260692309035,
#   'hybrid_score': 0.5256226551171951,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False},
#  {'product_id': 'P0216',
#   'name': 'Lalitpur Looms Accessories 216',
#   'category': 'Electronics',
#   'subcategory': 'Accessories',
#   'brand': 'Lalitpur Looms',
#   'price_npr': 1800,
#   'avg_rating': 3.6,
#   'in_stock': True,
#   'is_new_arrival': False,
#   'cf_score': 0.3571634319598238,
#   'cb_score': 0.6857428594366292,
#   'hybrid_score': 0.5050241743243862,
#   'alpha_used': 0.55,
#   'freshness_boost_applied': False,
#   'is_festival_recommendation': False}]
# new arrivals surfaced 7
